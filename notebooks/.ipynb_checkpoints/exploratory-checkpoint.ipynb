# %%
import os

os.chdir("./..")
data_folder = "./../data/"

# %%
import requests
from base64 import b64encode
import json
from datetime import date, timedelta, datetime

import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline  

from src import load_utilities as load_utils
from src import utilities as utils
from src import data_utilities as data_utils
import pandas as pd

# %%
season_games = utils.read_json("./../data/seasonal/games_2016-2017-regular.json")

# %%
games_pd = data_utils.get_season_games_table_from_json(season_games)

# %%
values_dict = {
    "away" : games_pd["score_total_away"].values,
    "home" : games_pd["score_total_home"].values
}

utils.plot_distributions(values_dict)
# Out:
# away
# avg_value: 104.0170731707317
# max_value: 143
# min_value: 68
#
# home
# avg_value: 107.16504065040651
# max_value: 149
# min_value: 64

# %%
games_pd["score_total_away"].mean()
