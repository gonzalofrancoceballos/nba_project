# %%
import os

os.chdir("./..")
data_folder = "./../data/"

# %%
import requests
from base64 import b64encode
import json
from datetime import date, timedelta, datetime

from src import utilities as utils
from src import load_utilities as load_utils

# %%
login_dict = utils.read_json("./../login.json")
login_key = login_dict["key"]
login = '{}:MYSPORTSFEEDS'.format(login_key).encode()

# %%
# Getting regular season games since 2016
for year in range(2016,2018):
    games_data = load_utils.get_seasonal_games(login,year_from=year, 
                                          year_to=(year+1), 
                                          season='regular', 
                                          to_file=True)
    
# Getting regular season games since 2016
for year in range(2016,2018):
    games_data = load_utils.get_seasonal_games(login,
                                          year_from=year, 
                                          year_to=(year+1), 
                                          season='playoff', to_file=True)
# Out:
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017/games.json
# Saving data to ... ./../data/seasonal/games_2016-2017-regular.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018/games.json
# Saving data to ... ./../data/seasonal/games_2017-2018-regular.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017/games.json
# Saving data to ... ./../data/seasonal/games_2016-2017-playoff.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018/games.json
# Saving data to ... ./../data/seasonal/games_2017-2018-playoff.json

# %%
# Season player logs
_ = load_utils.get_seasonal_player_logs(login, year_from=2016, year_to=2017,season='regular', to_file=True)
_ = load_utils.get_seasonal_player_logs(login, year_from=2016, year_to=2017,season='playoffs', to_file=True)
_ = load_utils.get_seasonal_player_logs(login, year_from=2017, year_to=2018,season='regular', to_file=True)
_ = load_utils.get_seasonal_player_logs(login, year_from=2017, year_to=2018,season='playoffs', to_file=True)
# Out:
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_gamelogs.json
# Saving data to ... ./../data/seasonal/player_logs_2016-2017-regular.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-playoffs/player_gamelogs.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_gamelogs.json
# Saving data to ... ./../data/seasonal/player_logs_2017-2018-regular.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-playoffs/player_gamelogs.json

# %%
# Daily player stats for 2016-2017 season

# Getting daily datess
dates = []
day_from = datetime.strptime(str(load_utils.season_dates["2016-2017"]["regular_season"]["from"]), '%Y%m%d')
day_to = datetime.strptime(str(load_utils.season_dates["2016-2017"]["regular_season"]["to"]), '%Y%m%d')

delta = day_to - day_from
for i in range(delta.days + 1):
    date_i = day_from + timedelta(i)
    dates.append(date_i.strftime('%Y%m%d'))

# Requesting data
for date in dates:
    daily_stats = load_utils.get_daily_player_stats(login,
                                                    date=date, 
                                                    year_from=2016,
                                                    year_to=2017,
                                                    season='regular', 
                                                    to_file=True)
# Out:
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161025
# Saving data to ... ./../data/daily/player_stats_regular-20161025.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161026
# Saving data to ... ./../data/daily/player_stats_regular-20161026.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161027
# Saving data to ... ./../data/daily/player_stats_regular-20161027.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161028
# Saving data to ... ./../data/daily/player_stats_regular-20161028.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161029
# Saving data to ... ./../data/daily/player_stats_regular-20161029.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161030
# Saving data to ... ./../data/daily/player_stats_regular-20161030.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161031
# Saving data to ... ./../data/daily/player_stats_regular-20161031.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161101
# Saving data to ... ./../data/daily/player_stats_regular-20161101.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161102
# Saving data to ... ./../data/daily/player_stats_regular-20161102.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161103
# Saving data to ... ./../data/daily/player_stats_regular-20161103.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161104
# Saving data to ... ./../data/daily/player_stats_regular-20161104.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161105
# Saving data to ... ./../data/daily/player_stats_regular-20161105.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161106
# Saving data to ... ./../data/daily/player_stats_regular-20161106.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161107
# Saving data to ... ./../data/daily/player_stats_regular-20161107.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20161108
# Saving data to ... ./../data/daily/player_stats_regular-20161108.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20
json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20170407
# Saving data to ... ./../data/daily/player_stats_regular-20170407.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20170408
# Saving data to ... ./../data/daily/player_stats_regular-20170408.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20170409
# Saving data to ... ./../data/daily/player_stats_regular-20170409.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20170410
# Saving data to ... ./../data/daily/player_stats_regular-20170410.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20170411
# Saving data to ... ./../data/daily/player_stats_regular-20170411.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/player_stats_totals.json?date=20170412
# Saving data to ... ./../data/daily/player_stats_regular-20170412.json

# %%
# Daily player stats for 2017-2018 season

# Getting daily dates
dates = []
day_from = datetime.strptime(str(load_utils.season_dates["2017-2018"]["regular_season"]["from"]), '%Y%m%d')
day_to = datetime.strptime(str(load_utils.season_dates["2017-2018"]["regular_season"]["to"]), '%Y%m%d')

delta = day_to - day_from
for i in range(delta.days + 1):
    date_i = day_from + timedelta(i)
    dates.append(date_i.strftime('%Y%m%d'))

    # Requesting date
for date in dates:
    daily_stats = load_utils.get_daily_player_stats(login,
                                                    date=date, 
                                                    year_from=2017,
                                                    year_to=2018,
                                                    season='regular', 
                                                    to_file=True)
# Out:
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171017
# Saving data to ... ./../data/daily/player_stats_regular-20171017.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171018
# Saving data to ... ./../data/daily/player_stats_regular-20171018.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171019
# Saving data to ... ./../data/daily/player_stats_regular-20171019.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171020
# Saving data to ... ./../data/daily/player_stats_regular-20171020.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171021
# Saving data to ... ./../data/daily/player_stats_regular-20171021.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171022
# Saving data to ... ./../data/daily/player_stats_regular-20171022.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171023
# Saving data to ... ./../data/daily/player_stats_regular-20171023.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171024
# Saving data to ... ./../data/daily/player_stats_regular-20171024.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171025
# Saving data to ... ./../data/daily/player_stats_regular-20171025.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171026
# Saving data to ... ./../data/daily/player_stats_regular-20171026.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171027
# Saving data to ... ./../data/daily/player_stats_regular-20171027.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171028
# Saving data to ... ./../data/daily/player_stats_regular-20171028.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171029
# Saving data to ... ./../data/daily/player_stats_regular-20171029.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171030
# Saving data to ... ./../data/daily/player_stats_regular-20171030.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171031
# Saving data to ... ./../data/daily/player_stats_regular-20171031.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171101
# Saving data to ... ./../data/daily/player_stats_regular-20171101.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171102
# Saving data to ... ./../data/daily/player_stats_regular-20171102.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171103
# Saving data to ... ./../data/daily/player_stats_regular-20171103.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171104
# Saving data to ... ./../data/daily/player_stats_regular-20171104.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171105
# Saving data to ... ./../data/daily/player_stats_regular-20171105.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171106
# Saving data to ... ./../data/daily/player_stats_regular-20171106.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171107
# Saving data to ... ./../data/daily/player_stats_regular-20171107.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171108
# Saving data to ... ./../data/daily/player_stats_regular-20171108.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171109
# Saving data to ... ./../data/daily/player_stats_regular-20171109.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171110
# Saving data to ... ./../data/daily/player_stats_regular-20171110.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171111
# Saving data to ... ./../data/daily/player_stats_regular-20171111.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171112
# Saving data to ... ./../data/daily/player_stats_regular-20171112.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171113
# Saving data to ... ./../data/daily/player_stats_regular-20171113.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171114
# Saving data to ... ./../data/daily/player_stats_regular-20171114.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171115
# Saving data to ... ./../data/daily/player_stats_regular-20171115.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171116
# Saving data to ... ./../data/daily/player_stats_regular-20171116.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171117
# Saving data to ... ./../data/daily/player_stats_regular-20171117.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171118
# Saving data to ... ./../data/daily/player_stats_regular-20171118.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20171119
# Saving data to ... ./../data/daily/player_stats_regular-20171119.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20
json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180227
# Saving data to ... ./../data/daily/player_stats_regular-20180227.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180228
# Saving data to ... ./../data/daily/player_stats_regular-20180228.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180301
# Saving data to ... ./../data/daily/player_stats_regular-20180301.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180302
# Saving data to ... ./../data/daily/player_stats_regular-20180302.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180303
# Saving data to ... ./../data/daily/player_stats_regular-20180303.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180304
# Saving data to ... ./../data/daily/player_stats_regular-20180304.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180305
# Saving data to ... ./../data/daily/player_stats_regular-20180305.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180306
# Saving data to ... ./../data/daily/player_stats_regular-20180306.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180307
# Saving data to ... ./../data/daily/player_stats_regular-20180307.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180308
# Saving data to ... ./../data/daily/player_stats_regular-20180308.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180309
# Saving data to ... ./../data/daily/player_stats_regular-20180309.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180310
# Saving data to ... ./../data/daily/player_stats_regular-20180310.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180311
# Saving data to ... ./../data/daily/player_stats_regular-20180311.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180312
# Saving data to ... ./../data/daily/player_stats_regular-20180312.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180313
# Saving data to ... ./../data/daily/player_stats_regular-20180313.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180314
# Saving data to ... ./../data/daily/player_stats_regular-20180314.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180315
# Saving data to ... ./../data/daily/player_stats_regular-20180315.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180316
# Saving data to ... ./../data/daily/player_stats_regular-20180316.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180317
# Saving data to ... ./../data/daily/player_stats_regular-20180317.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180318
# Saving data to ... ./../data/daily/player_stats_regular-20180318.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180319
# Saving data to ... ./../data/daily/player_stats_regular-20180319.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180320
# Saving data to ... ./../data/daily/player_stats_regular-20180320.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180321
# Saving data to ... ./../data/daily/player_stats_regular-20180321.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180322
# Saving data to ... ./../data/daily/player_stats_regular-20180322.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180323
# Saving data to ... ./../data/daily/player_stats_regular-20180323.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180324
# Saving data to ... ./../data/daily/player_stats_regular-20180324.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180325
# Saving data to ... ./../data/daily/player_stats_regular-20180325.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180326
# Saving data to ... ./../data/daily/player_stats_regular-20180326.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180327
# Saving data to ... ./../data/daily/player_stats_regular-20180327.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180328
# Saving data to ... ./../data/daily/player_stats_regular-20180328.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180329
# Saving data to ... ./../data/daily/player_stats_regular-20180329.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180330
# Saving data to ... ./../data/daily/player_stats_regular-20180330.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180331
# Saving data to ... ./../data/daily/player_stats_regular-20180331.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180401
# Saving data to ... ./../data/daily/player_stats_regular-20180401.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180402
# Saving data to ... ./../data/daily/player_stats_regular-20180402.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180403
# Saving data to ... ./../data/daily/player_stats_regular-20180403.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180404
# Saving data to ... ./../data/daily/player_stats_regular-20180404.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180405
# Saving data to ... ./../data/daily/player_stats_regular-20180405.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180406
# Saving data to ... ./../data/daily/player_stats_regular-20180406.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180407
# Saving data to ... ./../data/daily/player_stats_regular-20180407.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180408
# Saving data to ... ./../data/daily/player_stats_regular-20180408.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180409
# Saving data to ... ./../data/daily/player_stats_regular-20180409.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180410
# Saving data to ... ./../data/daily/player_stats_regular-20180410.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2017-2018-regular/player_stats_totals.json?date=20180411
# Saving data to ... ./../data/daily/player_stats_regular-20180411.json

# %%
def get_game_play_by_play(login, 
                          game_id,
                          year_from, 
                          year_to,
                          season='regular',
                          to_file=False,
                          data_path="./../data/"):
    '''
    Wrapper function to get play-by-play of a game
    
    :param login: (b'str) login for the request. Login format is b'{key}:MYSPORTSFEEDS'
    :param game_id: (str) data in YYYYMMDD format
    :param season: (str) 'regular' or 'playoff'
    :to_file: (boolean) to save json to disk
    :return: (dict) python dictionary containing requested data    
    '''

    address = 'https://api.mysportsfeeds.com/v2.0/pull/nba/{}-{}-{}/games/{}/playbyplay.json'.format(year_from,
                                                                                                      year_to,
                                                                                                      season,
                                                                                                      game_id)
    data = request_data(address, login)
    
    
    
    if to_file and len(data)>0:
        away_team = data["game"]["awayTeam"]["abbreviation"]
        home_team = data["game"]["homeTeam"]["abbreviation"]
        game_date = datetime.strptime(data["game"]["startTime"][0:10], '%Y-%m-%d').strftime('%Y%m%d')
        file_name = '{}game/game_play_by_play_{}-{}-{}-{}.json'.format(data_path, game_date, away_team, home_team, game_id)
        print("Saving data to ... {}".format(file_name))
        with open(file_name, 'w') as outfile:
            json.dump(data, outfile)
            
    return data

# %%
def request_data(address, login):
    '''
    Wrapper function to send a request to server
    
    :param address: (str) address for request
    :param login: (b'str) login for the request. Login format is b'{key}:MYSPORTSFEEDS'
    :return: (dict) python dictionary containing requested data
    '''

    userAndPass = b64encode(login).decode("ascii")
    print('Requesting ... {}'.format(address))
    r = requests.get(address,
                     headers = { 'Authorization' : 'Basic %s' %  userAndPass })
    
    str_content = r.content.decode("utf-8") 
    
    try: 
        py_dict_data = json.loads(str_content)
    except:
        py_dict_data = {}

    return py_dict_data

# %%
# Game play-by-play for 2016-17 and 2017-18 seasons

# Getting all game ids
with open('./../data/seasonal/games_2016-2017-regular.json') as f:
    season_games = json.load(f)
# Requesting data
for i in range(len(season_games["games"])):
    game_id = season_games["games"][i]["schedule"]["id"]
    
    data = get_game_play_by_play(login,
                             game_id = game_id,
                             year_from = 2016, 
                             year_to = 2017,to_file=True)


# Getting all game ids
with open('./../data/seasonal/games_2017-2018-regular.json') as f:
    season_games = json.load(f)
# Requesting data
for i in range(len(season_games["games"])):
    game_id = season_games["games"][i]["schedule"]["id"]
    
    data = load_utils.get_game_play_by_play(login, 
                             game_id = game_id,
                             year_from = 2017, 
                             year_to = 2018,to_file=True)
# Out:
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33941/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33942/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33943/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33944/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33945/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33946/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33947/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33948/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33949/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33950/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33951/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33952/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33953/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33954/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33955/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33956/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33957/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33958/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33959/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33960/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33961/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33962/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33963/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33964/playbyplay.json
# Requesting ... https://api.mysportsfeeds.com/v2.0/pull/nba/2016-2017-regular/games/33965/playbyplay.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-55730018b90f> in <module>()
#      11                              game_id = game_id,
#      12                              year_from = 2016,
# ---> 13                              year_to = 2017,to_file=True)
#      14
#      15
#
# <ipython-input-15-c31f1b2943ba> in get_game_play_by_play(login, game_id, year_from, year_to, season, to_file, data_path)
#      20                                                                                                       season,
#      21                                                                                                       game_id)
# ---> 22     data = request_data(address, login)
#      23
#      24
#
# <ipython-input-18-65bf0f2193ac> in request_data(address, login)
#      11     print('Requesting ... {}'.format(address))
#      12     r = requests.get(address,
# ---> 13                      headers = { 'Authorization' : 'Basic %s' %  userAndPass })
#      14
#      15     str_content = r.content.decode("utf-8")
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     842         # Force connect early to allow us to validate the connection.
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#     846         if not conn.is_verified:
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in connect(self)
#     282     def connect(self):
#     283         # Add certificate verification
# --> 284         conn = self._new_conn()
#     285
#     286         hostname = self.host
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# /home/gonzalo/anaconda3/lib/python3.6/site-packages/requests/packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:
